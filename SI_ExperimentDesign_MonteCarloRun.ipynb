# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from SI_Classes import SI_model, DataScaler
from System_Classes import CascadedTankSystem, LTISystem, WHSystem, CascadedTankSystem_Simplified
from SI_Functions import perform_experiment, generate_input_signals, generate_random_input_signals
from scipy.optimize import minimize
from scipy.optimize import approx_fprime
import pickle
# Set seed for reproducibility
seed=42
np.random.seed(seed)
torch.manual_seed(seed)

# %%
# Define the objective function
def objective_function(w_query, t_query_list, x0_query, si_model, lam):
    # Compute the surprise index
    suprise_index_norm, cunc_std_norm, suprise_index, y_query, unc_std, ppd_std, u_query, t_query = si_model.query_stepinput(t_query_list=t_query_list, w_query=w_query, x0_query=x0_query)
    unc_index = lam * (suprise_index_norm) + (1-lam) * (cunc_std_norm)
    loss = -np.log(unc_index)
    return loss

def numerical_jacobian(w_query, t_query_list, x0_query, si_model, lam):
    # epsilon = np.sqrt(np.finfo(float).eps)  # Small step size
    objective_function_wrt_w_query = lambda w_query: objective_function(w_query, t_query_list=t_query_list, x0_query=x0_query, si_model=si_model, lam=lam)
    epsilon = 1e-2
    return approx_fprime(w_query, objective_function_wrt_w_query, epsilon)

def callback(w_query_k, t_query_list, x0_query, si_model, lam):
    suprise_index_norm, cunc_std_norm, suprise_index, y_query, unc_std, ppd_std, u_query, t_query = si_model.query_stepinput(t_query_list=t_query_list, w_query=w_query_k, x0_query=x0_query)
    unc_index = lam * (suprise_index_norm) + (1-lam) * (cunc_std_norm)
    print("********")
    print(f"unc_index = {unc_index:.2f}")
    print(f"suprise_index = {suprise_index:.2f}")

# %%
start_idx = 0
mcrun_superdict = {}
tau_u_list = np.arange(0, 1, step=0.2)
tau_y_list = np.arange(0, 1, step=0.2)
run_idx = start_idx
for tau_u in tau_u_list:
    for tau_y in tau_y_list:
        mcrun_dict = {} 
        print("||||||||||||||||||||||||||||||||||||||||||||||||||||||||||")
        print(f"Monte Carlo Run Number {run_idx}")
    # True system - Cascaded Tanks
        sys = CascadedTankSystem(min_cons_hard_x_step=0, max_cons_hard_x_step=10, min_cons_hard_y_step=0, max_cons_hard_y_step=10, tau_u=tau_u, tau_y=tau_y, add_noise=True, noise_magnitude=0.0025, return_SNR=True)
        x0_denorm = np.array([5, 5, 5, 0])

        #############################################################################
        n_x = sys.n_x
        n_u = sys.n_u
        n_y = sys.n_y

        t_fit  = np.array([0, 15, 30, 45, 60, 75, 90, 105, 120, 135, 150, 165, 180])
        t_test = np.array([0, 15, 30, 45, 60, 75, 90])
        w_fit  = np.array([3, 2, 3, 4, 3.25, 1.75, 2.25, 3.75, 2.75, 2.25, 2.75, 3])
        w_test = np.array([3.25, 1.25, 4, 1.75, 3.5, 2])

        time_steps_fit_denorm, u_fit_denorm   = generate_input_signals(t_segments_list=t_fit, w_values=w_fit, n_u=n_u)
        time_steps_test_denorm, u_test_denorm = generate_input_signals(t_segments_list=t_test, w_values=w_test, n_u=n_u)


        y_fit_true_denorm,  x_fit_true_denorm  = sys(u_fit_denorm, x0_denorm)
        y_test_true_denorm, x_test_true_denorm = sys(u_test_denorm, x0_denorm)

        #############################################################################
        datascaler = DataScaler(
            mu_u=np.mean(u_fit_denorm, axis=0),
            mu_y=np.mean(y_fit_true_denorm, axis=0), 
            mu_x=np.mean(x_fit_true_denorm, axis=0),
            std_u=np.std(u_fit_denorm, axis=0),
            std_y=np.std(y_fit_true_denorm, axis=0), 
            std_x=np.std(x_fit_true_denorm, axis=0),
            mu_offset_u=0*np.mean(u_fit_denorm, axis=0),
            mu_offset_y=0*np.mean(y_fit_true_denorm, axis=0), 
            mu_offset_x=0*np.mean(x_fit_true_denorm, axis=0),  
            )

        # Normalizing the Data
        u_fit       = datascaler.normalize(u_fit_denorm, datascaler.mu_u, datascaler.std_u, datascaler.mu_offset_u)
        u_test      = datascaler.normalize(u_test_denorm, datascaler.mu_u, datascaler.std_u, datascaler.mu_offset_u)
        y_fit_true  = datascaler.normalize(y_fit_true_denorm, datascaler.mu_y, datascaler.std_y, datascaler.mu_offset_y)
        y_test_true = datascaler.normalize(y_test_true_denorm, datascaler.mu_y, datascaler.std_y, datascaler.mu_offset_y)
        x0          = datascaler.normalize(x0_denorm, datascaler.mu_x, datascaler.std_x, datascaler.mu_offset_x)

        # Signals for Counter-Factual Argument
        t_fit_cf       = np.copy(t_fit)
        u_fit_cf       = np.copy(u_fit)
        y_fit_true_cf  = np.copy(y_fit_true)
        u_test_cf      = np.copy(u_test)
        y_test_true_cf = np.copy(y_test_true)

        #############################################################################
        # Setup neural model structure
        hidden_size         = 8
        tau_prior           = 0.05
        sigma_noise         = 5e-2
        nn_fit_iters_base   = 100
        nn_fit_lr_base      = 1e-3
        nn_fit_iters_exp    = 175
        nn_fit_lr_exp       = 1e-4
        num_experiments     = 2
        num_experiments_min = 1
        t_query_list        = [0, 15, 30, 45]
        t_query_unit        = [0, 15, 30, 45]
        t_query_list_cf     = [0, 15, 30, 45]
        t_query_unit_cf     = [0, 15, 30, 45]
        experiment_length   = t_query_list[-1] - t_query_list[0]
        lam                 = 0.1
        lam_w               = 0.9
        w_querry_ub_denorm  = 4
        w_querry_lb_denorm  = 2
        n_opt_iter          = 10
        options             = {'maxiter': n_opt_iter, 'disp': True}
        tol_w_query         = 1e-3

        #############################################################################
        from NN_Classes import NeuralLinStateUpdate, NeuralLinOutput, CTSNeuralStateSpace
        si_model = SI_model(n_x, n_u, n_y, hidden_size, dtype=torch.float32, device=torch.device("cpu"), tau_prior=tau_prior, sigma_noise=sigma_noise, modify_si=False, f_class=NeuralLinStateUpdate, g_class=NeuralLinOutput)
        # si_model = SI_model(n_x, n_u, n_y, hidden_size, dtype=torch.float32, device=torch.device("cpu"), tau_prior=tau_prior, sigma_noise=sigma_noise, modify_si=False, f_class=CTSNeuralStateSpace, g_class=NeuralLinOutput)
        objective_function_wrt_w_query = lambda w_query: objective_function(w_query, t_query_list=t_query_list, x0_query=x0, si_model=si_model, lam=lam)
        numerical_jacobian_wrt_w_query = lambda w_query: numerical_jacobian(w_query, t_query_list=t_query_list, x0_query=x0, si_model=si_model, lam=lam)
        callback_wrt_w_query           = lambda w_query: callback(w_query, t_query_list=t_query_list, x0_query=x0, si_model=si_model, lam=lam)
        print("---------------------------------------------------------------------------------")
        print('Experiment Number #0:')
        print(" Training the Model on the Initial Dataset: ")
        _, _, loss_fit = si_model.nn_fit(u_fit=u_fit , y_fit=y_fit_true, x0=x0, num_iter=nn_fit_iters_base, lr=nn_fit_lr_base, print_freq=25, return_loss=True)
        y_test, _      = si_model.nn_predict(u_pred=u_test, x0_pred=x0)
        loss_test = np.mean((y_test - y_test_true)**2)
        print(f"Prediction Loss {loss_test:.4f}")
        _, _, _, _, _, _, _, _ = si_model.compute_fit_cov(u_fit=u_fit, x0_fit=x0)

        w_querry_ub     = datascaler.normalize(w_querry_ub_denorm, datascaler.mu_u, datascaler.std_u, datascaler.mu_offset_u)
        w_querry_lb     = datascaler.normalize(w_querry_lb_denorm, datascaler.mu_u, datascaler.std_u, datascaler.mu_offset_u)
        w_query_bounds  = [(w_querry_lb, w_querry_ub)]
        w_query_perturb = np.random.uniform(low=w_querry_lb, high=w_querry_ub, size=len(t_query_list)-1)
        w_query_opt     = w_query_perturb
        t_query_opt     = t_fit

        fitting_loss_history    = [loss_fit]
        prediction_loss_history = [loss_test]
        suprise_index_history   = []
        unc_index_history       = []

        for experiment_idx in range(1, num_experiments + 1):
            print("---------------------------------------------------------------------------------")
            print(f'Experiment Number #{experiment_idx}:')
            t_offset = t_query_opt[-1]
            t_query_list = t_offset + np.array(t_query_unit)
            w_query_init = lam_w * w_query_opt + (1- lam_w)*w_query_perturb 
            print("=====================")
            print(" Finding Optimal u: ")
            method = 'L-BFGS-B'
            result = minimize(objective_function_wrt_w_query, w_query_init, method=method, bounds=w_query_bounds, options=options, callback=callback_wrt_w_query, jac=numerical_jacobian_wrt_w_query)
            # method = 'nelder-mead'
            # result = minimize(objective_function_wrt_w_query, w_query_init, method=method, bounds=w_query_bounds, options=options)
            print(f"Optimization Result: x = {result.x}, Success: {result.success}, Message: {result.message}")
            w_query_opt_prev = w_query_opt
            w_query_opt = result.x
            #===========================================================================================================================================================================
            suprise_index_norm_opt, cunc_std_norm_opt, suprise_index_opt, y_query_opt, unc_std_opt, ppd_std_opt, u_query_opt, t_query_opt = si_model.query_stepinput(t_query_list=t_query_list, w_query=w_query_opt, x0_query=x0)
            #===========================================================================================================================================================================
            print(f'Optimized Surprise Index: {suprise_index_opt:.2f}')
            y_query_opt_true, _ = perform_experiment(sys, u_query_opt, x0, datascaler)
            print("=====================")
            #===========================================================================================================================================================================
            u_fit      = np.concat([u_fit, u_query_opt])
            y_fit_true = np.concat([y_fit_true, y_query_opt_true])
            print(" Retraining the Model on the Extended Dataset: ")
            y_fitted, _, loss_fit = si_model.nn_fit(u_fit=u_fit , y_fit=y_fit_true, x0=x0, num_iter=nn_fit_iters_exp, lr=nn_fit_lr_exp, print_freq=25, return_loss=True)
            y_test, x_test = si_model.nn_predict(u_pred=u_test, x0_pred=x0)
            loss_test = np.mean((y_test - y_test_true)**2)
            print(f"Prediction Loss {loss_test:.4f}")
            prediction_loss_history.append(loss_test)
            fitting_loss_history.append(loss_fit)
            suprise_index_history.append(suprise_index_opt)
            unc_index_history.append(lam * (suprise_index_norm_opt) + (1-lam) * (cunc_std_norm_opt))
            #===========================================================================================================================================================================
            _, _, _, _, _, _, _, _ = si_model.compute_fit_cov(u_fit=u_fit, x0_fit=x0)
            #===========================================================================================================================================================================
            # Stopping Criteria
            if np.linalg.norm(w_query_opt - w_query_opt_prev) < tol_w_query and experiment_idx >= num_experiments_min:
                print("Experiments Sequence Was Halted: ")
                print("Repeatative Input Sequence for Experiment")
                print(f"norm(w_query_opt, w_query_opt_prev) < tol_w_query: {np.linalg.norm(w_query_opt - w_query_opt_prev)} < {tol_w_query}")
                break
        #############################################################################
        si_model_cf = SI_model(n_x, n_u, n_y, hidden_size, dtype=torch.float32, device=torch.device("cpu"), tau_prior=tau_prior, sigma_noise=sigma_noise, modify_si=False)
        print("---------------------------------------------------------------------------------")
        print('Counter-Factual Experiment Number #0:')
        print(" Training the Model on the Initial Dataset: ")
        _, _, loss_fit_cf = si_model_cf.nn_fit(u_fit=u_fit_cf , y_fit=y_fit_true_cf, x0=x0, num_iter=nn_fit_iters_base, lr=nn_fit_lr_base, print_freq=25, return_loss=True)
        y_test_cf, _      = si_model_cf.nn_predict(u_pred=u_test, x0_pred=x0)
        loss_test_cf = np.mean((y_test_cf - y_test_true_cf)**2)
        print(f"Counter-Factual Prediction Loss {loss_test_cf:.4f}")
        _, _, _, _, _, _, _, _ = si_model_cf.compute_fit_cov(u_fit=u_fit_cf, x0_fit=x0)
        t_query_cf = t_fit_cf

        fitting_loss_history_cf    = [loss_fit_cf]
        prediction_loss_history_cf = [loss_test_cf]
        suprise_index_history_cf   = []
        unc_index_history_cf       = []

        for experiment_idx_cf in range(1, num_experiments + 1):
            print("---------------------------------------------------------------------------------")
            print(f'Counter-Factual Experiment Number #{experiment_idx_cf}:')
            t_offset_cf = t_query_cf[-1]
            t_query_list_cf = t_offset_cf + np.array(t_query_unit_cf)
            w_query_cf = np.random.uniform(low=w_querry_lb, high=w_querry_ub, size=len(t_query_list_cf)-1)
            #===========================================================================================================================================================================
            suprise_index_norm_cf, cunc_std_norm_cf, suprise_index_cf, y_query_cf, unc_std_cf, ppd_std_cf, u_query_cf, t_query_cf = si_model_cf.query_stepinput(t_query_list=t_query_list_cf, w_query=w_query_cf, x0_query=x0)
            #===========================================================================================================================================================================
            print(f'Optimized Surprise Index: {suprise_index_cf:.2f}')
            y_query_cf_true, _ = perform_experiment(sys, u_query_cf, x0, datascaler)
            print("=====================")
            #===========================================================================================================================================================================
            u_fit_cf      = np.concat([u_fit_cf, u_query_cf])
            y_fit_true_cf = np.concat([y_fit_true_cf, y_query_cf_true])
            print(" Retraining the Model on the Extended Dataset: ")
            y_fitted_cf, _, loss_fit_cf = si_model_cf.nn_fit(u_fit=u_fit_cf, y_fit=y_fit_true_cf, x0=x0, num_iter= nn_fit_iters_exp, lr=nn_fit_lr_exp, print_freq=25, return_loss=True)
            y_test_cf, _      = si_model_cf.nn_predict(u_pred=u_test_cf, x0_pred=x0)
            print(f"")
            loss_test_cf = np.mean((y_test_cf - y_test_true_cf)**2)
            print(f"Prediction Loss {loss_test_cf:.4f}")
            prediction_loss_history_cf.append(loss_test_cf)
            fitting_loss_history_cf.append(loss_fit_cf)
            suprise_index_history_cf.append(suprise_index_cf)
            unc_index_history_cf.append(lam * (suprise_index_norm_cf) + (1-lam) * (cunc_std_norm_cf))
            #===========================================================================================================================================================================
            _, _, _, _, _, _, _, _ = si_model_cf.compute_fit_cov(u_fit=u_fit_cf, x0_fit=x0)

        #############################################################################
        final_loss_test    = loss_test
        final_loss_test_cf = loss_test_cf
        print(f"Final Prediction Loss: {final_loss_test:.4f}")
        print(f"Final CF Prediction Loss: {final_loss_test_cf:.4f}")
        mcrun_dict["(tau_u, tau_y)"]                = (tau_u, tau_y)
        mcrun_dict["run_idx"]                       = run_idx
        mcrun_dict["prediction_loss_history"]       = prediction_loss_history
        mcrun_dict["prediction_loss_history_cf"]    = prediction_loss_history_cf
        mcrun_superdict["mc_run_dict"+f"{run_idx}"] = mcrun_dict
        run_idx = run_idx + 1
        print("||||||||||||||||||||||||||||||||||||||||||||||||||||||||||")
# Out:
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 0
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7853
# Iter 25 | Fit Loss 0.9970
# Iter 50 | Fit Loss 0.1788
# Iter 75 | Fit Loss 0.0326
# Iter 99 | Fit Loss 0.0139
# Prediction Loss 0.1195
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 1.12
# suprise_index = 12.09
# ********
# unc_index = 1.28
# suprise_index = 13.46
# ********
# unc_index = 1.94
# suprise_index = 24.27
# ********
# unc_index = 2.38
# suprise_index = 31.10
# ********
# unc_index = 2.39
# suprise_index = 31.21
# ********
# unc_index = 2.39
# suprise_index = 31.21
# ********
# unc_index = 2.43
# suprise_index = 31.35
# ********
# unc_index = 3.75
# suprise_index = 51.91
# ********
# unc_index = 3.75
# suprise_index = 51.92
# ********
# unc_index = 3.75
# suprise_index = 51.92
# Optimization Result: x = [ 1.57657903  0.04001311 -0.43630204], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 51.92
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.9361
# Iter 25 | Fit Loss 1.2285
# Iter 50 | Fit Loss 1.1091
# Iter 75 | Fit Loss 1.0197
# Iter 100 | Fit Loss 0.9277
# Iter 125 | Fit Loss 0.8764
# Iter 150 | Fit Loss 0.8388
# Iter 174 | Fit Loss 0.8102
# Prediction Loss 0.0928
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 2.48
# suprise_index = 17.15
# ********
# unc_index = 2.70
# suprise_index = 18.97
# ********
# unc_index = 2.80
# suprise_index = 19.77
# ********
# unc_index = 2.87
# suprise_index = 20.36
# ********
# unc_index = 3.04
# suprise_index = 21.61
# ********
# unc_index = 3.04
# suprise_index = 21.65
# ********
# unc_index = 3.04
# suprise_index = 21.65
# Optimization Result: x = [ 1.83679933 -0.27065873 -0.29607026], Success: True, Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
# Optimized Surprise Index: 21.65
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 1.8410
# Iter 25 | Fit Loss 1.0825
# Iter 50 | Fit Loss 0.9274
# Iter 75 | Fit Loss 0.8668
# Iter 100 | Fit Loss 0.8278
# Iter 125 | Fit Loss 0.7978
# Iter 150 | Fit Loss 0.7739
# Iter 174 | Fit Loss 0.7547
# Prediction Loss 0.0566
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7853
# Iter 25 | Fit Loss 0.9970
# Iter 50 | Fit Loss 0.1788
# Iter 75 | Fit Loss 0.0326
# Iter 99 | Fit Loss 0.0139
# Counter-Factual Prediction Loss 0.1195
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 5.79
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.0822
# Iter 25 | Fit Loss 1.1451
# Iter 50 | Fit Loss 1.0454
# Iter 75 | Fit Loss 0.9784
# Iter 100 | Fit Loss 0.9149
# Iter 125 | Fit Loss 0.8463
# Iter 150 | Fit Loss 0.8051
# Iter 174 | Fit Loss 0.7646
#
# Prediction Loss 0.1208
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 4.19
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.4686
# Iter 25 | Fit Loss 1.0298
# Iter 50 | Fit Loss 0.8647
# Iter 75 | Fit Loss 0.7188
# Iter 100 | Fit Loss 0.6280
# Iter 125 | Fit Loss 0.5459
# Iter 150 | Fit Loss 0.5058
# Iter 174 | Fit Loss 0.4864
#
# Prediction Loss 0.0828
# Final Prediction Loss: 0.0566
# Final CF Prediction Loss: 0.0828
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 1
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7851
# Iter 25 | Fit Loss 0.9979
# Iter 50 | Fit Loss 0.1772
# Iter 75 | Fit Loss 0.0323
# Iter 99 | Fit Loss 0.0127
# Prediction Loss 0.1196
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 2.41
# suprise_index = 31.66
# ********
# unc_index = 2.99
# suprise_index = 40.55
# ********
# unc_index = 3.31
# suprise_index = 45.38
# ********
# unc_index = 3.35
# suprise_index = 46.05
# ********
# unc_index = 3.44
# suprise_index = 47.39
# ********
# unc_index = 3.68
# suprise_index = 50.94
# ********
# unc_index = 5.14
# suprise_index = 73.57
# ********
# unc_index = 5.44
# suprise_index = 78.27
# ********
# unc_index = 5.49
# suprise_index = 79.09
# ********
# unc_index = 5.50
# suprise_index = 79.23
# Optimization Result: x = [ 1.83679933 -0.39163894 -0.28292767], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 79.23
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.8584
# Iter 25 | Fit Loss 1.2054
# Iter 50 | Fit Loss 1.0880
# Iter 75 | Fit Loss 1.0058
# Iter 100 | Fit Loss 0.9172
# Iter 125 | Fit Loss 0.8667
# Iter 150 | Fit Loss 0.8273
# Iter 174 | Fit Loss 0.7950
# Prediction Loss 0.0924
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 2.66
# suprise_index = 18.91
# ********
# unc_index = 2.79
# suprise_index = 20.02
# ********
# unc_index = 2.84
# suprise_index = 20.42
# ********
# unc_index = 2.85
# suprise_index = 20.51
# ********
# unc_index = 2.87
# suprise_index = 20.67
# ********
# unc_index = 2.89
# suprise_index = 20.83
# ********
# unc_index = 2.90
# suprise_index = 20.88
# ********
# unc_index = 2.97
# suprise_index = 21.49
# ********
# unc_index = 2.97
# suprise_index = 21.51
# ********
# unc_index = 2.97
# suprise_index = 21.51
# Optimization Result: x = [ 1.83679933 -0.26350034 -1.15958849], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 21.51
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 1.8945
# Iter 25 | Fit Loss 1.0846
# Iter 50 | Fit Loss 0.9263
# Iter 75 | Fit Loss 0.8469
# Iter 100 | Fit Loss 0.8038
# Iter 125 | Fit Loss 0.7720
# Iter 150 | Fit Loss 0.7469
# Iter 174 | Fit Loss 0.7267
# Prediction Loss 0.0606
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7851
# Iter 25 | Fit Loss 0.9979
# Iter 50 | Fit Loss 0.1772
# Iter 75 | Fit Loss 0.0323
# Iter 99 | Fit Loss 0.0127
# Counter-Factual Prediction Loss 0.1196
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 12.61
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.9181
# Iter 25 | Fit Loss 1.1715
# Iter 50 | Fit Loss 1.0587
# Iter 75 | Fit Loss 0.9883
# Iter 100 | Fit Loss 0.9075
# Iter 125 | Fit Loss 0.8586
# Iter 150 | Fit Loss 0.8252
# Iter 174 | Fit Loss 0.7969
#
# Prediction Loss 0.1086
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 3.72
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 1.9428
# Iter 25 | Fit Loss 1.0184
# Iter 50 | Fit Loss 0.8922
# Iter 75 | Fit Loss 0.7897
# Iter 100 | Fit Loss 0.6912
# Iter 125 | Fit Loss 0.6163
# Iter 150 | Fit Loss 0.5819
# Iter 174 | Fit Loss 0.5620
#
# Prediction Loss 0.0813
# Final Prediction Loss: 0.0606
# Final CF Prediction Loss: 0.0813
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 2
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7849
# Iter 25 | Fit Loss 0.9986
# Iter 50 | Fit Loss 0.1730
# Iter 75 | Fit Loss 0.0291
# Iter 99 | Fit Loss 0.0114
# Prediction Loss 0.1136
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 0.88
# suprise_index = 9.22
# ********
# unc_index = 2.07
# suprise_index = 25.58
# ********
# unc_index = 2.27
# suprise_index = 28.95
# ********
# unc_index = 2.79
# suprise_index = 36.90
# ********
# unc_index = 3.95
# suprise_index = 54.59
# ********
# unc_index = 3.96
# suprise_index = 54.77
# ********
# unc_index = 3.98
# suprise_index = 55.16
# ********
# unc_index = 4.44
# suprise_index = 62.11
# ********
# unc_index = 4.73
# suprise_index = 66.54
# ********
# unc_index = 4.81
# suprise_index = 67.89
# Optimization Result: x = [ 1.83679933 -0.42323207 -0.19755189], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 67.89
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.9371
# Iter 25 | Fit Loss 1.1827
# Iter 50 | Fit Loss 1.0725
# Iter 75 | Fit Loss 0.9907
# Iter 100 | Fit Loss 0.9044
# Iter 125 | Fit Loss 0.8542
# Iter 150 | Fit Loss 0.8152
# Iter 174 | Fit Loss 0.7836
# Prediction Loss 0.0854
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 2.48
# suprise_index = 17.42
# ********
# unc_index = 2.65
# suprise_index = 18.79
# ********
# unc_index = 2.66
# suprise_index = 18.89
# ********
# unc_index = 2.66
# suprise_index = 18.92
# ********
# unc_index = 2.66
# suprise_index = 18.92
# ********
# unc_index = 2.66
# suprise_index = 18.92
# Optimization Result: x = [ 1.83679933 -0.40501009 -0.10606592], Success: True, Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
# Optimized Surprise Index: 18.92
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 1.9277
# Iter 25 | Fit Loss 1.0771
# Iter 50 | Fit Loss 0.9201
# Iter 75 | Fit Loss 0.8394
# Iter 100 | Fit Loss 0.7956
# Iter 125 | Fit Loss 0.7637
# Iter 150 | Fit Loss 0.7384
# Iter 174 | Fit Loss 0.7183
# Prediction Loss 0.0525
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7849
# Iter 25 | Fit Loss 0.9986
# Iter 50 | Fit Loss 0.1730
# Iter 75 | Fit Loss 0.0291
# Iter 99 | Fit Loss 0.0114
# Counter-Factual Prediction Loss 0.1136
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 3.36
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.3705
# Iter 25 | Fit Loss 1.1325
# Iter 50 | Fit Loss 1.0447
# Iter 75 | Fit Loss 0.9924
# Iter 100 | Fit Loss 0.9318
# Iter 125 | Fit Loss 0.8760
# Iter 150 | Fit Loss 0.8390
# Iter 174 | Fit Loss 0.8024
#
# Prediction Loss 0.1284
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 7.36
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.5204
# Iter 25 | Fit Loss 1.1415
# Iter 50 | Fit Loss 0.9876
# Iter 75 | Fit Loss 0.8625
# Iter 100 | Fit Loss 0.7562
# Iter 125 | Fit Loss 0.6818
# Iter 150 | Fit Loss 0.6376
# Iter 174 | Fit Loss 0.6091
#
# Prediction Loss 0.1658
# Final Prediction Loss: 0.0525
# Final CF Prediction Loss: 0.1658
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 3
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7847
# Iter 25 | Fit Loss 0.9964
# Iter 50 | Fit Loss 0.1607
# Iter 75 | Fit Loss 0.0233
# Iter 99 | Fit Loss 0.0089
# Prediction Loss 0.1068
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 1.51
# suprise_index = 17.83
# ********
# unc_index = 1.63
# suprise_index = 19.13
# ********
# unc_index = 1.92
# suprise_index = 23.37
# ********
# unc_index = 2.43
# suprise_index = 30.79
# ********
# unc_index = 2.83
# suprise_index = 36.87
# ********
# unc_index = 2.85
# suprise_index = 37.15
# ********
# unc_index = 2.86
# suprise_index = 37.42
# ********
# unc_index = 3.10
# suprise_index = 40.92
# ********
# unc_index = 3.20
# suprise_index = 42.42
# ********
# unc_index = 3.24
# suprise_index = 43.04
# Optimization Result: x = [ 1.83679933 -0.43602326 -0.4523153 ], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 43.04
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.2426
# Iter 25 | Fit Loss 1.1554
# Iter 50 | Fit Loss 1.0589
# Iter 75 | Fit Loss 0.9720
# Iter 100 | Fit Loss 0.8862
# Iter 125 | Fit Loss 0.8327
# Iter 150 | Fit Loss 0.7929
# Iter 174 | Fit Loss 0.7621
# Prediction Loss 0.0757
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 2.27
# suprise_index = 15.50
# ********
# unc_index = 2.41
# suprise_index = 16.73
# ********
# unc_index = 2.41
# suprise_index = 16.77
# ********
# unc_index = 2.41
# suprise_index = 16.78
# ********
# unc_index = 2.41
# suprise_index = 16.78
# ********
# unc_index = 2.42
# suprise_index = 16.79
# ********
# unc_index = 2.43
# suprise_index = 16.87
# ********
# unc_index = 2.43
# suprise_index = 16.88
# ********
# unc_index = 2.43
# suprise_index = 16.95
# ********
# unc_index = 2.46
# suprise_index = 17.14
# Optimization Result: x = [ 1.83679933 -0.43965489 -1.25675744], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 17.14
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.2137
# Iter 25 | Fit Loss 1.0714
# Iter 50 | Fit Loss 0.9113
# Iter 75 | Fit Loss 0.8208
# Iter 100 | Fit Loss 0.7703
# Iter 125 | Fit Loss 0.7359
# Iter 150 | Fit Loss 0.7090
# Iter 174 | Fit Loss 0.6874
# Prediction Loss 0.0523
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7847
# Iter 25 | Fit Loss 0.9964
# Iter 50 | Fit Loss 0.1607
# Iter 75 | Fit Loss 0.0233
# Iter 99 | Fit Loss 0.0089
# Counter-Factual Prediction Loss 0.1068
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 5.95
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.4221
# Iter 25 | Fit Loss 1.1058
# Iter 50 | Fit Loss 1.0171
# Iter 75 | Fit Loss 0.9507
# Iter 100 | Fit Loss 0.8792
# Iter 125 | Fit Loss 0.8320
# Iter 150 | Fit Loss 0.8018
# Iter 174 | Fit Loss 0.7777
#
# Prediction Loss 0.1105
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 10.24
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 4.7678
# Iter 25 | Fit Loss 1.3236
# Iter 50 | Fit Loss 1.1988
# Iter 75 | Fit Loss 1.0783
# Iter 100 | Fit Loss 0.9864
# Iter 125 | Fit Loss 0.9172
# Iter 150 | Fit Loss 0.8591
# Iter 174 | Fit Loss 0.8099
#
# Prediction Loss 0.0826
# Final Prediction Loss: 0.0523
# Final CF Prediction Loss: 0.0826
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 4
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7859
# Iter 25 | Fit Loss 0.9620
# Iter 50 | Fit Loss 0.0997
# Iter 75 | Fit Loss 0.0122
# Iter 99 | Fit Loss 0.0060
# Prediction Loss 0.0955
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 0.50
# suprise_index = 3.65
# ********
# unc_index = 0.56
# suprise_index = 3.35
# ********
# unc_index = 0.68
# suprise_index = 3.01
# ********
# unc_index = 0.79
# suprise_index = 3.13
# Optimization Result: x = [-1.25675744 -1.25675744 -1.25675744], Success: True, Message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
# Optimized Surprise Index: 3.13
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 5.3766
# Iter 25 | Fit Loss 1.4879
# Iter 50 | Fit Loss 1.0889
# Iter 75 | Fit Loss 0.9141
# Iter 100 | Fit Loss 0.8627
# Iter 125 | Fit Loss 0.8429
# Iter 150 | Fit Loss 0.8297
# Iter 174 | Fit Loss 0.8178
# Prediction Loss 0.0992
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 0.64
# suprise_index = 2.76
# ********
# unc_index = 3.63
# suprise_index = 19.95
# ********
# unc_index = 3.82
# suprise_index = 21.13
# ********
# unc_index = 3.83
# suprise_index = 21.16
# ********
# unc_index = 3.87
# suprise_index = 21.42
# ********
# unc_index = 3.87
# suprise_index = 21.42
# ********
# unc_index = 3.87
# suprise_index = 21.42
# ********
# unc_index = 3.88
# suprise_index = 21.43
# ********
# unc_index = 3.88
# suprise_index = 21.43
# ********
# unc_index = 3.88
# suprise_index = 21.43
# Optimization Result: x = [ 1.83679933 -0.16494155 -1.0060193 ], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 21.43
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 7.6776
# Iter 25 | Fit Loss 1.8334
# Iter 50 | Fit Loss 1.4597
# Iter 75 | Fit Loss 1.3788
# Iter 100 | Fit Loss 1.3173
# Iter 125 | Fit Loss 1.2558
# Iter 150 | Fit Loss 1.1900
# Iter 174 | Fit Loss 1.1270
# Prediction Loss 0.1226
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7859
# Iter 25 | Fit Loss 0.9620
# Iter 50 | Fit Loss 0.0997
# Iter 75 | Fit Loss 0.0122
# Iter 99 | Fit Loss 0.0060
# Counter-Factual Prediction Loss 0.0955
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 4.66
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 5.2643
# Iter 25 | Fit Loss 1.4883
# Iter 50 | Fit Loss 1.0491
# Iter 75 | Fit Loss 0.8839
# Iter 100 | Fit Loss 0.8374
# Iter 125 | Fit Loss 0.8192
# Iter 150 | Fit Loss 0.8060
# Iter 174 | Fit Loss 0.7940
#
# Prediction Loss 0.0882
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 3.92
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.9110
# Iter 25 | Fit Loss 1.1231
# Iter 50 | Fit Loss 1.0430
# Iter 75 | Fit Loss 0.9486
# Iter 100 | Fit Loss 0.8611
# Iter 125 | Fit Loss 0.7793
# Iter 150 | Fit Loss 0.7246
# Iter 174 | Fit Loss 0.7036
#
# Prediction Loss 0.0603
# Final Prediction Loss: 0.1226
# Final CF Prediction Loss: 0.0603
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 5
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7763
# Iter 25 | Fit Loss 1.0153
# Iter 50 | Fit Loss 0.1762
# Iter 75 | Fit Loss 0.0310
# Iter 99 | Fit Loss 0.0125
# Prediction Loss 0.1133
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 2.43
# suprise_index = 31.30
# ********
# unc_index = 2.58
# suprise_index = 33.74
# ********
# unc_index = 3.07
# suprise_index = 41.28
# ********
# unc_index = 3.25
# suprise_index = 43.74
# ********
# unc_index = 4.56
# suprise_index = 63.41
# ********
# unc_index = 4.58
# suprise_index = 63.73
# ********
# unc_index = 4.65
# suprise_index = 64.77
# ********
# unc_index = 5.20
# suprise_index = 72.90
# ********
# unc_index = 5.44
# suprise_index = 76.48
# ********
# unc_index = 5.49
# suprise_index = 77.22
# Optimization Result: x = [ 1.83679933 -0.39271607 -0.13599698], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 77.22
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.2602
# Iter 25 | Fit Loss 1.1569
# Iter 50 | Fit Loss 1.0530
# Iter 75 | Fit Loss 0.9541
# Iter 100 | Fit Loss 0.8755
# Iter 125 | Fit Loss 0.8282
# Iter 150 | Fit Loss 0.7948
# Iter 174 | Fit Loss 0.7696
# Prediction Loss 0.0673
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 2.58
# suprise_index = 18.71
# ********
# unc_index = 2.68
# suprise_index = 19.54
# ********
# unc_index = 2.70
# suprise_index = 19.76
# ********
# unc_index = 2.71
# suprise_index = 19.80
# ********
# unc_index = 2.72
# suprise_index = 19.89
# ********
# unc_index = 2.83
# suprise_index = 20.78
# ********
# unc_index = 2.83
# suprise_index = 20.79
# ********
# unc_index = 2.83
# suprise_index = 20.82
# ********
# unc_index = 2.83
# suprise_index = 20.82
# ********
# unc_index = 2.83
# suprise_index = 20.82
# Optimization Result: x = [ 1.83679933 -0.17139909 -1.25675744], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 20.82
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.0216
# Iter 25 | Fit Loss 1.0763
# Iter 50 | Fit Loss 0.9180
# Iter 75 | Fit Loss 0.8427
# Iter 100 | Fit Loss 0.8009
# Iter 125 | Fit Loss 0.7695
# Iter 150 | Fit Loss 0.7444
# Iter 174 | Fit Loss 0.7242
# Prediction Loss 0.0503
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7763
# Iter 25 | Fit Loss 1.0153
# Iter 50 | Fit Loss 0.1762
# Iter 75 | Fit Loss 0.0310
# Iter 99 | Fit Loss 0.0125
# Counter-Factual Prediction Loss 0.1133
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 6.19
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.4745
# Iter 25 | Fit Loss 1.0841
# Iter 50 | Fit Loss 1.0070
# Iter 75 | Fit Loss 0.9346
# Iter 100 | Fit Loss 0.8680
# Iter 125 | Fit Loss 0.8313
# Iter 150 | Fit Loss 0.8081
# Iter 174 | Fit Loss 0.7906
#
# Prediction Loss 0.0955
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 11.96
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.3627
# Iter 25 | Fit Loss 1.0322
# Iter 50 | Fit Loss 0.8552
# Iter 75 | Fit Loss 0.7797
# Iter 100 | Fit Loss 0.7457
# Iter 125 | Fit Loss 0.7226
# Iter 150 | Fit Loss 0.7046
# Iter 174 | Fit Loss 0.6905
#
# Prediction Loss 0.0693
# Final Prediction Loss: 0.0503
# Final CF Prediction Loss: 0.0693
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 6
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7761
# Iter 25 | Fit Loss 1.0158
# Iter 50 | Fit Loss 0.1741
# Iter 75 | Fit Loss 0.0289
# Iter 99 | Fit Loss 0.0115
# Prediction Loss 0.1108
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 1.42
# suprise_index = 16.58
# ********
# unc_index = 1.71
# suprise_index = 20.22
# ********
# unc_index = 3.37
# suprise_index = 45.72
# ********
# unc_index = 3.39
# suprise_index = 45.99
# ********
# unc_index = 3.46
# suprise_index = 46.91
# ********
# unc_index = 4.74
# suprise_index = 66.33
# ********
# unc_index = 4.75
# suprise_index = 66.41
# ********
# unc_index = 4.79
# suprise_index = 67.00
# ********
# unc_index = 4.81
# suprise_index = 67.27
# Optimization Result: x = [ 1.83679933 -0.40668417 -0.14457082], Success: False, Message: ABNORMAL:
# Optimized Surprise Index: 67.27
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.2384
# Iter 25 | Fit Loss 1.1507
# Iter 50 | Fit Loss 1.0475
# Iter 75 | Fit Loss 0.9479
# Iter 100 | Fit Loss 0.8705
# Iter 125 | Fit Loss 0.8231
# Iter 150 | Fit Loss 0.7893
# Iter 174 | Fit Loss 0.7638
# Prediction Loss 0.0635
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 2.54
# suprise_index = 18.22
# ********
# unc_index = 2.59
# suprise_index = 18.66
# ********
# unc_index = 2.63
# suprise_index = 19.02
# ********
# unc_index = 2.63
# suprise_index = 19.09
# ********
# unc_index = 2.64
# suprise_index = 19.10
# ********
# unc_index = 2.64
# suprise_index = 19.18
# ********
# unc_index = 2.66
# suprise_index = 19.30
# ********
# unc_index = 2.73
# suprise_index = 19.87
# ********
# unc_index = 2.73
# suprise_index = 19.87
# Optimization Result: x = [ 1.83679933 -0.21254754 -1.25675744], Success: True, Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
# Optimized Surprise Index: 19.87
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.0703
# Iter 25 | Fit Loss 1.0775
# Iter 50 | Fit Loss 0.9183
# Iter 75 | Fit Loss 0.8385
# Iter 100 | Fit Loss 0.7951
# Iter 125 | Fit Loss 0.7633
# Iter 150 | Fit Loss 0.7380
# Iter 174 | Fit Loss 0.7176
# Prediction Loss 0.0475
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7761
# Iter 25 | Fit Loss 1.0158
# Iter 50 | Fit Loss 0.1741
# Iter 75 | Fit Loss 0.0289
# Iter 99 | Fit Loss 0.0115
# Counter-Factual Prediction Loss 0.1108
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 3.07
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.5986
# Iter 25 | Fit Loss 1.0821
# Iter 50 | Fit Loss 0.9999
# Iter 75 | Fit Loss 0.9296
# Iter 100 | Fit Loss 0.8657
# Iter 125 | Fit Loss 0.8305
# Iter 150 | Fit Loss 0.8087
# Iter 174 | Fit Loss 0.7919
#
# Prediction Loss 0.1206
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 4.62
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 4.8411
# Iter 25 | Fit Loss 1.1519
# Iter 50 | Fit Loss 1.0597
# Iter 75 | Fit Loss 0.9699
# Iter 100 | Fit Loss 0.8948
# Iter 125 | Fit Loss 0.8330
# Iter 150 | Fit Loss 0.7825
# Iter 174 | Fit Loss 0.7407
#
# Prediction Loss 0.1221
# Final Prediction Loss: 0.0475
# Final CF Prediction Loss: 0.1221
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 7
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7759
# Iter 25 | Fit Loss 1.0159
# Iter 50 | Fit Loss 0.1697
# Iter 75 | Fit Loss 0.0259
# Iter 99 | Fit Loss 0.0100
# Prediction Loss 0.1061
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 0.54
# suprise_index = 5.55
# ********
# unc_index = 1.85
# suprise_index = 23.02
# ********
# unc_index = 1.86
# suprise_index = 22.57
# ********
# unc_index = 3.93
# suprise_index = 53.96
# ********
# unc_index = 3.96
# suprise_index = 54.43
# ********
# unc_index = 4.00
# suprise_index = 55.01
# ********
# unc_index = 4.00
# suprise_index = 55.12
# Optimization Result: x = [ 1.83679933 -0.41883133 -0.20745977], Success: False, Message: ABNORMAL:
# Optimized Surprise Index: 55.12
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.3239
# Iter 25 | Fit Loss 1.1394
# Iter 50 | Fit Loss 1.0391
# Iter 75 | Fit Loss 0.9365
# Iter 100 | Fit Loss 0.8615
# Iter 125 | Fit Loss 0.8145
# Iter 150 | Fit Loss 0.7807
# Iter 174 | Fit Loss 0.7553
# Prediction Loss 0.0572
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 2.41
# suprise_index = 17.09
# ********
# unc_index = 2.46
# suprise_index = 17.46
# ********
# unc_index = 2.47
# suprise_index = 17.58
# ********
# unc_index = 2.47
# suprise_index = 17.61
# ********
# unc_index = 2.47
# suprise_index = 17.62
# ********
# unc_index = 2.48
# suprise_index = 17.68
# ********
# unc_index = 2.48
# suprise_index = 17.72
# ********
# unc_index = 2.49
# suprise_index = 17.76
# ********
# unc_index = 2.54
# suprise_index = 18.22
# ********
# unc_index = 2.55
# suprise_index = 18.26
# Optimization Result: x = [ 1.83679933 -0.2520698  -1.25675744], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 18.26
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.2070
# Iter 25 | Fit Loss 1.0848
# Iter 50 | Fit Loss 0.9253
# Iter 75 | Fit Loss 0.8380
# Iter 100 | Fit Loss 0.7900
# Iter 125 | Fit Loss 0.7567
# Iter 150 | Fit Loss 0.7302
# Iter 174 | Fit Loss 0.7092
# Prediction Loss 0.0417
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7759
# Iter 25 | Fit Loss 1.0159
# Iter 50 | Fit Loss 0.1697
# Iter 75 | Fit Loss 0.0259
# Iter 99 | Fit Loss 0.0100
# Counter-Factual Prediction Loss 0.1061
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 4.36
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.6502
# Iter 25 | Fit Loss 1.1791
# Iter 50 | Fit Loss 1.0907
# Iter 75 | Fit Loss 0.9966
# Iter 100 | Fit Loss 0.9346
# Iter 125 | Fit Loss 0.8996
# Iter 150 | Fit Loss 0.8763
# Iter 174 | Fit Loss 0.8586
#
# Prediction Loss 0.0745
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 13.54
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.3984
# Iter 25 | Fit Loss 1.1455
# Iter 50 | Fit Loss 0.9833
# Iter 75 | Fit Loss 0.8678
# Iter 100 | Fit Loss 0.8057
# Iter 125 | Fit Loss 0.7701
# Iter 150 | Fit Loss 0.7440
# Iter 174 | Fit Loss 0.7235
#
# Prediction Loss 0.1983
# Final Prediction Loss: 0.0417
# Final CF Prediction Loss: 0.1983
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 8
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7756
# Iter 25 | Fit Loss 1.0121
# Iter 50 | Fit Loss 0.1569
# Iter 75 | Fit Loss 0.0196
# Iter 99 | Fit Loss 0.0075
# Prediction Loss 0.0913
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 0.54
# suprise_index = 4.25
# ********
# unc_index = 0.67
# suprise_index = 5.67
# ********
# unc_index = 1.45
# suprise_index = 12.67
# ********
# unc_index = 1.51
# suprise_index = 12.64
# ********
# unc_index = 2.71
# suprise_index = 34.33
# ********
# unc_index = 2.71
# suprise_index = 34.41
# ********
# unc_index = 3.16
# suprise_index = 41.72
# ********
# unc_index = 3.19
# suprise_index = 42.19
# ********
# unc_index = 3.19
# suprise_index = 42.32
# ********
# unc_index = 3.19
# suprise_index = 42.33
# Optimization Result: x = [ 1.83679933 -0.46138093 -0.23831872], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 42.33
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.7994
# Iter 25 | Fit Loss 1.1461
# Iter 50 | Fit Loss 1.0129
# Iter 75 | Fit Loss 0.9109
# Iter 100 | Fit Loss 0.8438
# Iter 125 | Fit Loss 0.7991
# Iter 150 | Fit Loss 0.7667
# Iter 174 | Fit Loss 0.7424
# Prediction Loss 0.0489
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 2.14
# suprise_index = 14.63
# ********
# unc_index = 2.16
# suprise_index = 14.82
# ********
# unc_index = 2.17
# suprise_index = 15.01
# ********
# unc_index = 2.18
# suprise_index = 15.02
# ********
# unc_index = 2.18
# suprise_index = 15.03
# ********
# unc_index = 2.20
# suprise_index = 15.27
# ********
# unc_index = 2.21
# suprise_index = 15.32
# ********
# unc_index = 2.22
# suprise_index = 15.39
# ********
# unc_index = 2.22
# suprise_index = 15.39
# ********
# unc_index = 2.23
# suprise_index = 15.47
# Optimization Result: x = [ 1.83679933 -0.32226929 -1.13202386], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 15.47
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.4974
# Iter 25 | Fit Loss 1.0980
# Iter 50 | Fit Loss 0.9391
# Iter 75 | Fit Loss 0.8376
# Iter 100 | Fit Loss 0.7787
# Iter 125 | Fit Loss 0.7412
# Iter 150 | Fit Loss 0.7127
# Iter 174 | Fit Loss 0.6901
# Prediction Loss 0.0309
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7756
# Iter 25 | Fit Loss 1.0121
# Iter 50 | Fit Loss 0.1569
# Iter 75 | Fit Loss 0.0196
# Iter 99 | Fit Loss 0.0075
# Counter-Factual Prediction Loss 0.0913
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 16.50
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.8838
# Iter 25 | Fit Loss 1.1850
# Iter 50 | Fit Loss 1.0511
# Iter 75 | Fit Loss 0.9503
# Iter 100 | Fit Loss 0.8844
# Iter 125 | Fit Loss 0.8412
# Iter 150 | Fit Loss 0.8106
# Iter 174 | Fit Loss 0.7879
#
# Prediction Loss 0.0412
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 4.00
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.3250
# Iter 25 | Fit Loss 1.1974
# Iter 50 | Fit Loss 1.0540
# Iter 75 | Fit Loss 0.9538
# Iter 100 | Fit Loss 0.8873
# Iter 125 | Fit Loss 0.8430
# Iter 150 | Fit Loss 0.8113
# Iter 174 | Fit Loss 0.7884
#
# Prediction Loss 0.0513
# Final Prediction Loss: 0.0309
# Final CF Prediction Loss: 0.0513
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 9
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7759
# Iter 25 | Fit Loss 0.9759
# Iter 50 | Fit Loss 0.0898
# Iter 75 | Fit Loss 0.0103
# Iter 99 | Fit Loss 0.0054
# Prediction Loss 0.0851
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 1.76
# suprise_index = 19.93
# ********
# unc_index = 1.88
# suprise_index = 21.19
# ********
# unc_index = 2.21
# suprise_index = 26.86
# ********
# unc_index = 2.21
# suprise_index = 27.03
# ********
# unc_index = 2.23
# suprise_index = 27.39
# ********
# unc_index = 2.25
# suprise_index = 27.80
# ********
# unc_index = 2.26
# suprise_index = 27.97
# ********
# unc_index = 2.37
# suprise_index = 29.56
# ********
# unc_index = 2.37
# suprise_index = 29.59
# ********
# unc_index = 2.37
# suprise_index = 29.59
# Optimization Result: x = [ 1.83679933 -0.62331847 -0.04368474], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 29.59
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 5.2153
# Iter 25 | Fit Loss 1.6828
# Iter 50 | Fit Loss 1.0676
# Iter 75 | Fit Loss 0.8417
# Iter 100 | Fit Loss 0.7865
# Iter 125 | Fit Loss 0.7612
# Iter 150 | Fit Loss 0.7421
# Iter 174 | Fit Loss 0.7248
# Prediction Loss 0.0457
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 1.80
# suprise_index = 11.58
# ********
# unc_index = 1.81
# suprise_index = 11.66
# ********
# unc_index = 1.81
# suprise_index = 11.70
# ********
# unc_index = 1.82
# suprise_index = 11.78
# ********
# unc_index = 1.84
# suprise_index = 11.99
# ********
# unc_index = 1.85
# suprise_index = 12.01
# ********
# unc_index = 1.85
# suprise_index = 12.06
# ********
# unc_index = 1.87
# suprise_index = 12.17
# ********
# unc_index = 1.87
# suprise_index = 12.17
# ********
# unc_index = 1.87
# suprise_index = 12.17
# Optimization Result: x = [ 1.83679933 -0.52798368 -1.25675744], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 12.17
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.1440
# Iter 25 | Fit Loss 0.9532
# Iter 50 | Fit Loss 0.7764
# Iter 75 | Fit Loss 0.6371
# Iter 100 | Fit Loss 0.5432
# Iter 125 | Fit Loss 0.5145
# Iter 150 | Fit Loss 0.4986
# Iter 174 | Fit Loss 0.4879
# Prediction Loss 0.0448
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7759
# Iter 25 | Fit Loss 0.9759
# Iter 50 | Fit Loss 0.0898
# Iter 75 | Fit Loss 0.0103
# Iter 99 | Fit Loss 0.0054
# Counter-Factual Prediction Loss 0.0851
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 4.47
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 5.3200
# Iter 25 | Fit Loss 1.6895
# Iter 50 | Fit Loss 1.1028
# Iter 75 | Fit Loss 0.8509
# Iter 100 | Fit Loss 0.8037
# Iter 125 | Fit Loss 0.7896
# Iter 150 | Fit Loss 0.7801
# Iter 174 | Fit Loss 0.7710
#
# Prediction Loss 0.0599
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 9.31
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.5549
# Iter 25 | Fit Loss 0.9316
# Iter 50 | Fit Loss 0.8077
# Iter 75 | Fit Loss 0.7282
# Iter 100 | Fit Loss 0.6858
# Iter 125 | Fit Loss 0.6629
# Iter 150 | Fit Loss 0.6471
# Iter 174 | Fit Loss 0.6349
#
# Prediction Loss 0.0474
# Final Prediction Loss: 0.0448
# Final CF Prediction Loss: 0.0474
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 10
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7581
# Iter 25 | Fit Loss 1.0743
# Iter 50 | Fit Loss 0.2022
# Iter 75 | Fit Loss 0.0274
# Iter 99 | Fit Loss 0.0126
# Prediction Loss 0.0563
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 0.73
# suprise_index = 5.38
# ********
# unc_index = 1.51
# suprise_index = 12.74
# ********
# unc_index = 1.74
# suprise_index = 14.83
# ********
# unc_index = 2.44
# suprise_index = 17.00
# ********
# unc_index = 3.15
# suprise_index = 34.35
# ********
# unc_index = 3.74
# suprise_index = 46.37
# ********
# unc_index = 3.82
# suprise_index = 48.12
# ********
# unc_index = 3.97
# suprise_index = 50.43
# ********
# unc_index = 4.13
# suprise_index = 52.98
# ********
# unc_index = 4.31
# suprise_index = 56.29
# Optimization Result: x = [ 1.83679933 -0.2840327   0.80964695], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 56.29
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 4.5572
# Iter 25 | Fit Loss 3.1030
# Iter 50 | Fit Loss 2.7302
# Iter 75 | Fit Loss 2.4911
# Iter 100 | Fit Loss 2.2329
# Iter 125 | Fit Loss 2.0139
# Iter 150 | Fit Loss 1.7789
# Iter 174 | Fit Loss 1.5235
# Prediction Loss 0.1335
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 2.28
# suprise_index = 21.55
# ********
# unc_index = 2.35
# suprise_index = 22.16
# ********
# unc_index = 2.36
# suprise_index = 22.18
# ********
# unc_index = 2.36
# suprise_index = 22.17
# ********
# unc_index = 2.36
# suprise_index = 22.17
# ********
# unc_index = 2.38
# suprise_index = 21.71
# ********
# unc_index = 2.40
# suprise_index = 21.51
# ********
# unc_index = 2.40
# suprise_index = 21.61
# ********
# unc_index = 2.40
# suprise_index = 21.61
# Optimization Result: x = [1.83679933 0.53121793 1.83679933], Success: True, Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
# Optimized Surprise Index: 21.61
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.2871
# Iter 25 | Fit Loss 1.6916
# Iter 50 | Fit Loss 1.4925
# Iter 75 | Fit Loss 1.3087
# Iter 100 | Fit Loss 1.1558
# Iter 125 | Fit Loss 1.0124
# Iter 150 | Fit Loss 0.9220
# Iter 174 | Fit Loss 0.8704
# Prediction Loss 0.1526
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7581
# Iter 25 | Fit Loss 1.0743
# Iter 50 | Fit Loss 0.2022
# Iter 75 | Fit Loss 0.0274
# Iter 99 | Fit Loss 0.0126
# Counter-Factual Prediction Loss 0.0563
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 14.23
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 4.6765
# Iter 25 | Fit Loss 3.2707
# Iter 50 | Fit Loss 2.8435
# Iter 75 | Fit Loss 2.4860
# Iter 100 | Fit Loss 2.2381
# Iter 125 | Fit Loss 1.9324
# Iter 150 | Fit Loss 1.5364
# Iter 174 | Fit Loss 1.1040
#
# Prediction Loss 0.3422
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 6.67
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.2477
# Iter 25 | Fit Loss 1.2878
# Iter 50 | Fit Loss 1.1267
# Iter 75 | Fit Loss 1.0737
# Iter 100 | Fit Loss 1.0330
# Iter 125 | Fit Loss 0.9961
# Iter 150 | Fit Loss 0.9624
# Iter 174 | Fit Loss 0.9330
#
# Prediction Loss 0.1403
# Final Prediction Loss: 0.1526
# Final CF Prediction Loss: 0.1403
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 11
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7579
# Iter 25 | Fit Loss 1.0748
# Iter 50 | Fit Loss 0.1975
# Iter 75 | Fit Loss 0.0242
# Iter 99 | Fit Loss 0.0091
# Prediction Loss 0.0497
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 0.64
# suprise_index = 2.79
# ********
# unc_index = 0.65
# suprise_index = 2.78
# ********
# unc_index = 0.79
# suprise_index = 2.88
# Optimization Result: x = [-1.25675744 -1.25675744 -1.25675744], Success: True, Message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
# Optimized Surprise Index: 2.88
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 4.7333
# Iter 25 | Fit Loss 1.5801
# Iter 50 | Fit Loss 1.1135
# Iter 75 | Fit Loss 0.9010
# Iter 100 | Fit Loss 0.8459
# Iter 125 | Fit Loss 0.8256
# Iter 150 | Fit Loss 0.8131
# Iter 174 | Fit Loss 0.8023
# Prediction Loss 0.0500
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 0.62
# suprise_index = 2.50
# ********
# unc_index = 0.64
# suprise_index = 2.70
# ********
# unc_index = 2.30
# suprise_index = 13.32
# ********
# unc_index = 6.28
# suprise_index = 39.47
# ********
# unc_index = 6.31
# suprise_index = 39.64
# ********
# unc_index = 6.31
# suprise_index = 39.67
# ********
# unc_index = 6.33
# suprise_index = 39.82
# ********
# unc_index = 6.49
# suprise_index = 40.87
# ********
# unc_index = 6.52
# suprise_index = 41.08
# ********
# unc_index = 6.52
# suprise_index = 41.11
# Optimization Result: x = [ 1.83679933 -0.19890601 -0.66349632], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 41.11
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 5.6945
# Iter 25 | Fit Loss 1.5055
# Iter 50 | Fit Loss 1.2647
# Iter 75 | Fit Loss 1.2066
# Iter 100 | Fit Loss 1.1624
# Iter 125 | Fit Loss 1.1211
# Iter 150 | Fit Loss 1.0812
# Iter 174 | Fit Loss 1.0424
# Prediction Loss 0.0866
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7579
# Iter 25 | Fit Loss 1.0748
# Iter 50 | Fit Loss 0.1975
# Iter 75 | Fit Loss 0.0242
# Iter 99 | Fit Loss 0.0091
# Counter-Factual Prediction Loss 0.0497
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 5.24
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 5.1037
# Iter 25 | Fit Loss 1.7658
# Iter 50 | Fit Loss 1.1047
# Iter 75 | Fit Loss 0.8589
# Iter 100 | Fit Loss 0.8096
# Iter 125 | Fit Loss 0.7904
# Iter 150 | Fit Loss 0.7764
# Iter 174 | Fit Loss 0.7639
#
# Prediction Loss 0.0407
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 3.91
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 1.9608
# Iter 25 | Fit Loss 0.9946
# Iter 50 | Fit Loss 0.8742
# Iter 75 | Fit Loss 0.7978
# Iter 100 | Fit Loss 0.7483
# Iter 125 | Fit Loss 0.7139
# Iter 150 | Fit Loss 0.6876
# Iter 174 | Fit Loss 0.6674
#
# Prediction Loss 0.0890
# Final Prediction Loss: 0.0866
# Final CF Prediction Loss: 0.0890
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 12
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.7575
# Iter 25 | Fit Loss 1.0746
# Iter 50 | Fit Loss 0.1928
# Iter 75 | Fit Loss 0.0202
# Iter 99 | Fit Loss 0.0061
# Prediction Loss 0.0479
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 0.60
# suprise_index = 3.07
# ********
# unc_index = 0.72
# suprise_index = 2.83
# ********
# unc_index = 0.73
# suprise_index = 2.83
# ********
# unc_index = 0.74
# suprise_index = 2.83
# Optimization Result: x = [-1.25675744 -1.25675744 -1.25675744], Success: True, Message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
# Optimized Surprise Index: 2.83
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 4.4597
# Iter 25 | Fit Loss 1.3211
# Iter 50 | Fit Loss 0.9787
# Iter 75 | Fit Loss 0.8741
# Iter 100 | Fit Loss 0.8364
# Iter 125 | Fit Loss 0.8158
# Iter 150 | Fit Loss 0.8016
# Iter 174 | Fit Loss 0.7898
# Prediction Loss 0.0551
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 0.64
# suprise_index = 2.60
# ********
# unc_index = 0.65
# suprise_index = 2.63
# ********
# unc_index = 0.66
# suprise_index = 2.75
# ********
# unc_index = 2.15
# suprise_index = 11.90
# ********
# unc_index = 2.56
# suprise_index = 13.89
# ********
# unc_index = 5.60
# suprise_index = 33.54
# ********
# unc_index = 5.62
# suprise_index = 33.65
# ********
# unc_index = 5.62
# suprise_index = 33.65
# ********
# unc_index = 5.62
# suprise_index = 33.65
# ********
# unc_index = 5.62
# suprise_index = 33.65
# Optimization Result: x = [ 1.83679933 -0.02062914 -1.00688424], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# ...
# Iter 25 | Fit Loss 0.4598
# Iter 50 | Fit Loss 0.0278
# Iter 75 | Fit Loss 0.0033
# Iter 99 | Fit Loss 0.0022
# Counter-Factual Prediction Loss 0.0181
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 9.51
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.2791
# Iter 25 | Fit Loss 1.7270
# Iter 50 | Fit Loss 1.2835
# Iter 75 | Fit Loss 0.7760
# Iter 100 | Fit Loss 0.5865
# Iter 125 | Fit Loss 0.5309
# Iter 150 | Fit Loss 0.5153
# Iter 174 | Fit Loss 0.5065
#
# Prediction Loss 0.0485
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 7.31
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 1.1956
# Iter 25 | Fit Loss 0.6426
# Iter 50 | Fit Loss 0.5568
# Iter 75 | Fit Loss 0.5011
# Iter 100 | Fit Loss 0.4627
# Iter 125 | Fit Loss 0.4355
# Iter 150 | Fit Loss 0.4137
# Iter 174 | Fit Loss 0.3957
#
# Prediction Loss 0.0468
# Final Prediction Loss: 0.0436
# Final CF Prediction Loss: 0.0468
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 21
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.6283
# Iter 25 | Fit Loss 0.4507
# Iter 50 | Fit Loss 0.0270
# Iter 75 | Fit Loss 0.0034
# Iter 99 | Fit Loss 0.0025
# Prediction Loss 0.0186
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 0.80
# suprise_index = 3.68
# ********
# unc_index = 0.93
# suprise_index = 3.69
# ********
# unc_index = 0.99
# suprise_index = 3.80
# ********
# unc_index = 1.01
# suprise_index = 3.83
# ********
# unc_index = 1.01
# suprise_index = 3.83
# ********
# unc_index = 1.01
# suprise_index = 3.83
# ********
# unc_index = 1.01
# suprise_index = 3.83
# ********
# unc_index = 1.01
# suprise_index = 3.83
# Optimization Result: x = [-1.25675744 -1.25675744 -1.24852322], Success: True, Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
# Optimized Surprise Index: 3.83
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.6663
# Iter 25 | Fit Loss 1.8124
# Iter 50 | Fit Loss 1.2544
# Iter 75 | Fit Loss 0.7648
# Iter 100 | Fit Loss 0.6468
# Iter 125 | Fit Loss 0.6069
# Iter 150 | Fit Loss 0.5868
# Iter 174 | Fit Loss 0.5702
# Prediction Loss 0.0519
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 0.71
# suprise_index = 2.79
# ********
# unc_index = 0.71
# suprise_index = 2.77
# ********
# unc_index = 0.72
# suprise_index = 2.77
# Optimization Result: x = [-1.25675744 -1.25675744 -1.25675744], Success: True, Message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
# Optimized Surprise Index: 2.77
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 4.7906
# Iter 25 | Fit Loss 1.2978
# Iter 50 | Fit Loss 1.1133
# Iter 75 | Fit Loss 1.0073
# Iter 100 | Fit Loss 0.9383
# Iter 125 | Fit Loss 0.8862
# Iter 150 | Fit Loss 0.8397
# Iter 174 | Fit Loss 0.7955
# Prediction Loss 0.0434
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.6283
# Iter 25 | Fit Loss 0.4507
# Iter 50 | Fit Loss 0.0270
# Iter 75 | Fit Loss 0.0034
# Iter 99 | Fit Loss 0.0025
# Counter-Factual Prediction Loss 0.0186
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 13.00
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.2083
# Iter 25 | Fit Loss 1.7047
# Iter 50 | Fit Loss 1.2651
# Iter 75 | Fit Loss 0.7749
# Iter 100 | Fit Loss 0.5776
# Iter 125 | Fit Loss 0.5222
# Iter 150 | Fit Loss 0.5041
# Iter 174 | Fit Loss 0.4923
#
# Prediction Loss 0.0489
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 4.61
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 0.9534
# Iter 25 | Fit Loss 0.6618
# Iter 50 | Fit Loss 0.5883
# Iter 75 | Fit Loss 0.5325
# Iter 100 | Fit Loss 0.4908
# Iter 125 | Fit Loss 0.4568
# Iter 150 | Fit Loss 0.4273
# Iter 174 | Fit Loss 0.4090
#
# Prediction Loss 0.0121
# Final Prediction Loss: 0.0434
# Final CF Prediction Loss: 0.0121
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 22
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.6277
# Iter 25 | Fit Loss 0.4360
# Iter 50 | Fit Loss 0.0260
# Iter 75 | Fit Loss 0.0037
# Iter 99 | Fit Loss 0.0029
# Prediction Loss 0.0195
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 1.76
# suprise_index = 14.04
# ********
# unc_index = 1.78
# suprise_index = 14.56
# ********
# unc_index = 1.78
# suprise_index = 14.61
# ********
# unc_index = 1.83
# suprise_index = 15.14
# ********
# unc_index = 1.86
# suprise_index = 15.52
# ********
# unc_index = 1.87
# suprise_index = 15.52
# ********
# unc_index = 1.87
# suprise_index = 15.53
# ********
# unc_index = 1.87
# suprise_index = 15.53
# ********
# unc_index = 1.87
# suprise_index = 15.53
# Optimization Result: x = [ 1.83679933  0.44569668 -1.25675744], Success: True, Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
# Optimized Surprise Index: 15.53
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.2051
# Iter 25 | Fit Loss 1.7167
# Iter 50 | Fit Loss 1.2702
# Iter 75 | Fit Loss 0.7740
# Iter 100 | Fit Loss 0.5580
# Iter 125 | Fit Loss 0.4948
# Iter 150 | Fit Loss 0.4733
# Iter 174 | Fit Loss 0.4596
# Prediction Loss 0.0582
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 1.36
# suprise_index = 8.44
# ********
# unc_index = 1.37
# suprise_index = 8.55
# ********
# unc_index = 1.37
# suprise_index = 8.70
# ********
# unc_index = 1.37
# suprise_index = 8.67
# ********
# unc_index = 1.37
# suprise_index = 8.70
# ********
# unc_index = 1.38
# suprise_index = 8.82
# ********
# unc_index = 1.38
# suprise_index = 8.82
# Optimization Result: x = [ 1.83679933 -0.09125483 -1.25675744], Success: True, Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
# Optimized Surprise Index: 8.82
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 1.1358
# Iter 25 | Fit Loss 0.6092
# Iter 50 | Fit Loss 0.5173
# Iter 75 | Fit Loss 0.4594
# Iter 100 | Fit Loss 0.4202
# Iter 125 | Fit Loss 0.3912
# Iter 150 | Fit Loss 0.3660
# Iter 174 | Fit Loss 0.3441
# Prediction Loss 0.0994
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.6277
# Iter 25 | Fit Loss 0.4360
# Iter 50 | Fit Loss 0.0260
# Iter 75 | Fit Loss 0.0037
# Iter 99 | Fit Loss 0.0029
# Counter-Factual Prediction Loss 0.0195
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 3.71
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.5853
# Iter 25 | Fit Loss 1.8597
# Iter 50 | Fit Loss 1.3177
# Iter 75 | Fit Loss 0.7609
# Iter 100 | Fit Loss 0.6035
# Iter 125 | Fit Loss 0.5626
# Iter 150 | Fit Loss 0.5494
# Iter 174 | Fit Loss 0.5391
#
# Prediction Loss 0.0898
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 5.42
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 1.8062
# Iter 25 | Fit Loss 0.7097
# Iter 50 | Fit Loss 0.6044
# Iter 75 | Fit Loss 0.5605
# Iter 100 | Fit Loss 0.5289
# Iter 125 | Fit Loss 0.5037
# Iter 150 | Fit Loss 0.4820
# Iter 174 | Fit Loss 0.4627
#
# Prediction Loss 0.1421
# Final Prediction Loss: 0.0994
# Final CF Prediction Loss: 0.1421
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 23
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.6263
# Iter 25 | Fit Loss 0.4110
# Iter 50 | Fit Loss 0.0240
# Iter 75 | Fit Loss 0.0045
# Iter 99 | Fit Loss 0.0038
# Prediction Loss 0.0220
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 1.17
# suprise_index = 8.32
# ********
# unc_index = 1.71
# suprise_index = 13.82
# ********
# unc_index = 1.74
# suprise_index = 13.81
# ********
# unc_index = 1.78
# suprise_index = 14.49
# ********
# unc_index = 1.79
# suprise_index = 14.75
# ********
# unc_index = 1.80
# suprise_index = 14.86
# ********
# unc_index = 1.80
# suprise_index = 14.88
# ********
# unc_index = 1.80
# suprise_index = 14.96
# ********
# unc_index = 1.80
# suprise_index = 14.96
# ********
# unc_index = 1.81
# suprise_index = 14.96
# Optimization Result: x = [ 1.83679933  0.45464411 -1.25675744], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 14.96
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.2105
# Iter 25 | Fit Loss 1.7506
# Iter 50 | Fit Loss 1.2991
# Iter 75 | Fit Loss 0.7939
# Iter 100 | Fit Loss 0.5395
# Iter 125 | Fit Loss 0.4750
# Iter 150 | Fit Loss 0.4531
# Iter 174 | Fit Loss 0.4330
# Prediction Loss 0.0665
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 1.31
# suprise_index = 8.51
# ********
# unc_index = 1.33
# suprise_index = 8.82
# ********
# unc_index = 1.33
# suprise_index = 8.89
# ********
# unc_index = 1.33
# suprise_index = 8.89
# ********
# unc_index = 1.33
# suprise_index = 8.89
# ********
# unc_index = 1.33
# suprise_index = 8.89
# Optimization Result: x = [ 1.83679933 -0.26636233 -1.25675744], Success: True, Message: CONVERGENCE: RELATIVE REDUCTION OF F <= FACTR*EPSMCH
# Optimized Surprise Index: 8.89
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 1.0497
# Iter 25 | Fit Loss 0.5587
# Iter 50 | Fit Loss 0.4715
# Iter 75 | Fit Loss 0.4213
# Iter 100 | Fit Loss 0.3888
# Iter 125 | Fit Loss 0.3630
# Iter 150 | Fit Loss 0.3412
# Iter 174 | Fit Loss 0.3250
# Prediction Loss 0.1135
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.6263
# Iter 25 | Fit Loss 0.4110
# Iter 50 | Fit Loss 0.0240
# Iter 75 | Fit Loss 0.0045
# Iter 99 | Fit Loss 0.0038
# Counter-Factual Prediction Loss 0.0220
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 6.58
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.3348
# Iter 25 | Fit Loss 1.7940
# Iter 50 | Fit Loss 1.3654
# Iter 75 | Fit Loss 0.8346
# Iter 100 | Fit Loss 0.5953
# Iter 125 | Fit Loss 0.5440
# Iter 150 | Fit Loss 0.5301
# Iter 174 | Fit Loss 0.5205
#
# Prediction Loss 0.0351
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 4.51
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 0.8957
# Iter 25 | Fit Loss 0.5724
# Iter 50 | Fit Loss 0.5192
# Iter 75 | Fit Loss 0.4851
# Iter 100 | Fit Loss 0.4585
# Iter 125 | Fit Loss 0.4353
# Iter 150 | Fit Loss 0.4150
# Iter 174 | Fit Loss 0.3982
#
# Prediction Loss 0.0199
# Final Prediction Loss: 0.1135
# Final CF Prediction Loss: 0.0199
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# Monte Carlo Run Number 24
# ---------------------------------------------------------------------------------
# Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.6196
# Iter 25 | Fit Loss 0.3666
# Iter 50 | Fit Loss 0.0206
# Iter 75 | Fit Loss 0.0088
# Iter 99 | Fit Loss 0.0070
# Prediction Loss 0.0307
# ---------------------------------------------------------------------------------
# Experiment Number #1:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 0.75
# suprise_index = 5.71
# ********
# unc_index = 1.42
# suprise_index = 11.11
# ********
# unc_index = 1.44
# suprise_index = 11.27
# ********
# unc_index = 1.44
# suprise_index = 11.33
# ********
# unc_index = 1.44
# suprise_index = 11.49
# ********
# unc_index = 1.45
# suprise_index = 11.43
# ********
# unc_index = 1.45
# suprise_index = 11.34
# Optimization Result: x = [1.83679933 1.83679933 1.83679933], Success: True, Message: CONVERGENCE: NORM OF PROJECTED GRADIENT <= PGTOL
# Optimized Surprise Index: 11.34
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 2.9252
# Iter 25 | Fit Loss 1.6481
# Iter 50 | Fit Loss 1.2720
# Iter 75 | Fit Loss 0.8746
# Iter 100 | Fit Loss 0.4749
# Iter 125 | Fit Loss 0.4039
# Iter 150 | Fit Loss 0.3827
# Iter 174 | Fit Loss 0.3678
# Prediction Loss 0.0986
# ---------------------------------------------------------------------------------
# Experiment Number #2:
# =====================
#  Finding Optimal u:
# ********
# unc_index = 1.20
# suprise_index = 6.97
# ********
# unc_index = 1.20
# suprise_index = 6.99
# ********
# unc_index = 1.26
# suprise_index = 7.53
# ********
# unc_index = 1.26
# suprise_index = 7.56
# ********
# unc_index = 1.29
# suprise_index = 8.04
# ********
# unc_index = 1.30
# suprise_index = 8.14
# ********
# unc_index = 1.34
# suprise_index = 8.96
# ********
# unc_index = 1.35
# suprise_index = 9.03
# ********
# unc_index = 1.35
# suprise_index = 9.05
# ********
# unc_index = 1.35
# suprise_index = 9.05
# Optimization Result: x = [ 1.83679933 -0.10932446 -1.25675744], Success: False, Message: STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
# Optimized Surprise Index: 9.05
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 0.7772
# Iter 25 | Fit Loss 0.4808
# Iter 50 | Fit Loss 0.4527
# Iter 75 | Fit Loss 0.4362
# Iter 100 | Fit Loss 0.4256
# Iter 125 | Fit Loss 0.4173
# Iter 150 | Fit Loss 0.4095
# Iter 174 | Fit Loss 0.4020
# Prediction Loss 0.1396
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #0:
#  Training the Model on the Initial Dataset:
# Iter 0 | Fit Loss 1.6196
# Iter 25 | Fit Loss 0.3666
# Iter 50 | Fit Loss 0.0206
# Iter 75 | Fit Loss 0.0088
# Iter 99 | Fit Loss 0.0070
# Counter-Factual Prediction Loss 0.0307
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #1:
# Optimized Surprise Index: 9.34
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 3.2151
# Iter 25 | Fit Loss 1.8364
# Iter 50 | Fit Loss 1.3753
# Iter 75 | Fit Loss 0.8870
# Iter 100 | Fit Loss 0.5092
# Iter 125 | Fit Loss 0.4391
# Iter 150 | Fit Loss 0.3979
# Iter 174 | Fit Loss 0.3677
#
# Prediction Loss 0.0946
# ---------------------------------------------------------------------------------
# Counter-Factual Experiment Number #2:
# Optimized Surprise Index: 4.63
# =====================
#  Retraining the Model on the Extended Dataset:
# Iter 0 | Fit Loss 0.4838
# Iter 25 | Fit Loss 0.4063
# Iter 50 | Fit Loss 0.3701
# Iter 75 | Fit Loss 0.3453
# Iter 100 | Fit Loss 0.3283
# Iter 125 | Fit Loss 0.3144
# Iter 150 | Fit Loss 0.3011
# Iter 174 | Fit Loss 0.2886
#
# Prediction Loss 0.0343
# Final Prediction Loss: 0.1396
# Final CF Prediction Loss: 0.0343
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||

# %%
with open('mcrun_superdict.pkl', 'wb') as file:
    pickle.dump(mcrun_superdict, file)

# %%
mcrun_superdict
# Out:
# {'mc_run_dict0': {'(tau_u, tau_y)': (np.float64(0.0), np.float64(0.0)),
#   'run_idx': 0,
#   'prediction_loss_history': [np.float64(0.11945176595916897),
#    np.float64(0.0928196230795609),
#    np.float64(0.05657602323329804)],
#   'prediction_loss_history_cf': [np.float64(0.11945176595916897),
#    np.float64(0.1207927052625332),
#    np.float64(0.08284597289696226)]},
#  'mc_run_dict1': {'(tau_u, tau_y)': (np.float64(0.0), np.float64(0.2)),
#   'run_idx': 1,
#   'prediction_loss_history': [np.float64(0.11957632237468256),
#    np.float64(0.09236777249626207),
#    np.float64(0.06063891882341135)],
#   'prediction_loss_history_cf': [np.float64(0.11957632237468256),
#    np.float64(0.10856371900132863),
#    np.float64(0.081259532915233)]},
#  'mc_run_dict2': {'(tau_u, tau_y)': (np.float64(0.0), np.float64(0.4)),
#   'run_idx': 2,
#   'prediction_loss_history': [np.float64(0.11363064780766642),
#    np.float64(0.08536715671787788),
#    np.float64(0.052488748477638195)],
#   'prediction_loss_history_cf': [np.float64(0.11363064780766642),
#    np.float64(0.12837958162464347),
#    np.float64(0.1658109140057992)]},
#  'mc_run_dict3': {'(tau_u, tau_y)': (np.float64(0.0),
#    np.float64(0.6000000000000001)),
#   'run_idx': 3,
#   'prediction_loss_history': [np.float64(0.10677943978180511),
#    np.float64(0.07574505591592327),
#    np.float64(0.05229416822750422)],
#   'prediction_loss_history_cf': [np.float64(0.10677943978180511),
#    np.float64(0.11045425195845841),
#    np.float64(0.08255257925928289)]},
#  'mc_run_dict4': {'(tau_u, tau_y)': (np.float64(0.0), np.float64(0.8)),
#   'run_idx': 4,
#   'prediction_loss_history': [np.float64(0.09554500022116541),
#    np.float64(0.09922585051561479),
#    np.float64(0.12259865289840761)],
#   'prediction_loss_history_cf': [np.float64(0.09554500022116541),
#    np.float64(0.08815081878282212),
#    np.float64(0.060339739117329955)]},
#  'mc_run_dict5': {'(tau_u, tau_y)': (np.float64(0.2), np.float64(0.0)),
#   'run_idx': 5,
#   'prediction_loss_history': [np.float64(0.11329842873936245),
#    np.float64(0.06730731603070687),
#    np.float64(0.05025429026585833)],
#   'prediction_loss_history_cf': [np.float64(0.11329842873936245),
#    np.float64(0.09551775018468849),
#    np.float64(0.06929353818732421)]},
#  'mc_run_dict6': {'(tau_u, tau_y)': (np.float64(0.2), np.float64(0.2)),
#   'run_idx': 6,
#   'prediction_loss_history': [np.float64(0.11076428740033775),
#    np.float64(0.06354344291554989),
#    np.float64(0.047484778810386104)],
#   'prediction_loss_history_cf': [np.float64(0.11076428740033775),
#    np.float64(0.12061243732751321),
#    np.float64(0.12211926030483791)]},
#  'mc_run_dict7': {'(tau_u, tau_y)': (np.float64(0.2), np.float64(0.4)),
#   'run_idx': 7,
#   'prediction_loss_history': [np.float64(0.10611873677495923),
#    np.float64(0.057248018915050596),
#    np.float64(0.04170917416751121)],
#   'prediction_loss_history_cf': [np.float64(0.10611873677495923),
#    np.float64(0.074458182632628),
#    np.float64(0.19827120529859954)]},
#  'mc_run_dict8': {'(tau_u, tau_y)': (np.float64(0.2),
#    np.float64(0.6000000000000001)),
#   'run_idx': 8,
#   'prediction_loss_history': [np.float64(0.09128629380709918),
#    np.float64(0.04892281190667374),
#    np.float64(0.03092729543730063)],
#   'prediction_loss_history_cf': [np.float64(0.09128629380709918),
#    np.float64(0.0411501830085152),
#    np.float64(0.05133557054886882)]},
#  'mc_run_dict9': {'(tau_u, tau_y)': (np.float64(0.2), np.float64(0.8)),
#   'run_idx': 9,
#   'prediction_loss_history': [np.float64(0.08510494163698855),
#    np.float64(0.045676040200434115),
#    np.float64(0.044766322004917855)],
#   'prediction_loss_history_cf': [np.float64(0.08510494163698855),
#    np.float64(0.05987681643863762),
#    np.float64(0.04735901970000907)]},
#  'mc_run_dict10': {'(tau_u, tau_y)': (np.float64(0.4), np.float64(0.0)),
#   'run_idx': 10,
#   'prediction_loss_history': [np.float64(0.05634197505107388),
#    np.float64(0.1334707291548658),
#    np.float64(0.15262218381005535)],
#   'prediction_loss_history_cf': [np.float64(0.05634197505107388),
#    np.float64(0.34219928271965533),
#    np.float64(0.14029273877834925)]},
#  'mc_run_dict11': {'(tau_u, tau_y)': (np.float64(0.4), np.float64(0.2)),
#   'run_idx': 11,
#   'prediction_loss_history': [np.float64(0.04973284762740452),
#    np.float64(0.05002086824556337),
#    np.float64(0.08664424148676471)],
#   'prediction_loss_history_cf': [np.float64(0.04973284762740452),
#    np.float64(0.04069125212484166),
#    np.float64(0.08896663127999077)]},
#  'mc_run_dict12': {'(tau_u, tau_y)': (np.float64(0.4), np.float64(0.4)),
#   'run_idx': 12,
#   'prediction_loss_history': [np.float64(0.04786476649369571),
#    np.float64(0.055115527556113035),
#    np.float64(0.07753019197375088)],
#   'prediction_loss_history_cf': [np.float64(0.04786476649369571),
#    np.float64(0.05605505998019866),
#    np.float64(0.19023032993910066)]},
#  'mc_run_dict13': {'(tau_u, tau_y)': (np.float64(0.4),
#    np.float64(0.6000000000000001)),
#   'run_idx': 13,
#   'prediction_loss_history': [np.float64(0.048006855659072055),
#    np.float64(0.057877080763887465),
#    np.float64(0.03520319354584857)],
#   'prediction_loss_history_cf': [np.float64(0.048006855659072055),
#    np.float64(0.023129674095887006),
#    np.float64(0.0368908269083205)]},
#  'mc_run_dict14': {'(tau_u, tau_y)': (np.float64(0.4), np.float64(0.8)),
#   'run_idx': 14,
#   'prediction_loss_history': [np.float64(0.058702574181432904),
#    np.float64(0.07885902883647633),
#    np.float64(0.14658279939734772)],
#   'prediction_loss_history_cf': [np.float64(0.058702574181432904),
#    np.float64(0.045709327847158934),
#    np.float64(0.08234974298057414)]},
#  'mc_run_dict15': {'(tau_u, tau_y)': (np.float64(0.6000000000000001),
#    np.float64(0.0)),
#   'run_idx': 15,
#   'prediction_loss_history': [np.float64(0.035556691113517516),
#    np.float64(0.06818481655928296),
#    np.float64(0.0911087415785896)],
#   'prediction_loss_history_cf': [np.float64(0.035556691113517516),
#    np.float64(0.014800617869548767),
#    np.float64(0.2102138196705042)]},
#  'mc_run_dict16': {'(tau_u, tau_y)': (np.float64(0.6000000000000001),
#    np.float64(0.2)),
#   'run_idx': 16,
#   'prediction_loss_history': [np.float64(0.03465241072745258),
#    np.float64(0.08316476227325478),
#    np.float64(0.06326304277662607)],
#   'prediction_loss_history_cf': [np.float64(0.03465241072745258),
#    np.float64(0.0279883132356092),
#    np.float64(0.01158145646902043)]},
#  'mc_run_dict17': {'(tau_u, tau_y)': (np.float64(0.6000000000000001),
#    np.float64(0.4)),
#   'run_idx': 17,
#   'prediction_loss_history': [np.float64(0.034066817011161994),
#    np.float64(0.06691788196955274),
#    np.float64(0.09251546258348096)],
#   'prediction_loss_history_cf': [np.float64(0.034066817011161994),
#    np.float64(0.03311356376140207),
#    np.float64(0.006401543526705487)]},
#  'mc_run_dict18': {'(tau_u, tau_y)': (np.float64(0.6000000000000001),
#    np.float64(0.6000000000000001)),
#   'run_idx': 18,
#   'prediction_loss_history': [np.float64(0.03572779575451216),
#    np.float64(0.06877208041150462),
#    np.float64(0.09775246234528455)],
#   'prediction_loss_history_cf': [np.float64(0.03572779575451216),
#    np.float64(0.05856518239907899),
#    np.float64(0.013832775199968691)]},
#  'mc_run_dict19': {'(tau_u, tau_y)': (np.float64(0.6000000000000001),
#    np.float64(0.8)),
#   'run_idx': 19,
#   'prediction_loss_history': [np.float64(0.05274644948422243),
#    np.float64(0.10604801075584425),
#    np.float64(0.04534054108830946)],
#   'prediction_loss_history_cf': [np.float64(0.05274644948422243),
#    np.float64(0.04862961237465551),
#    np.float64(0.028024812721603093)]},
#  'mc_run_dict20': {'(tau_u, tau_y)': (np.float64(0.8), np.float64(0.0)),
#   'run_idx': 20,
#   'prediction_loss_history': [np.float64(0.018095997435458096),
#    np.float64(0.04997836183721682),
#    np.float64(0.04356359014601041)],
#   'prediction_loss_history_cf': [np.float64(0.018095997435458096),
#    np.float64(0.04850943093687213),
#    np.float64(0.046844826570120485)]},
#  'mc_run_dict21': {'(tau_u, tau_y)': (np.float64(0.8), np.float64(0.2)),
#   'run_idx': 21,
#   'prediction_loss_history': [np.float64(0.018570771008009895),
#    np.float64(0.051865891890747265),
#    np.float64(0.043401107821613424)],
#   'prediction_loss_history_cf': [np.float64(0.018570771008009895),
#    np.float64(0.048909584762595965),
#    np.float64(0.012127902111406807)]},
#  'mc_run_dict22': {'(tau_u, tau_y)': (np.float64(0.8), np.float64(0.4)),
#   'run_idx': 22,
#   'prediction_loss_history': [np.float64(0.01954886576218033),
#    np.float64(0.05817075534056023),
#    np.float64(0.09942408349657171)],
#   'prediction_loss_history_cf': [np.float64(0.01954886576218033),
#    np.float64(0.0897760695129567),
#    np.float64(0.14209201956207956)]},
#  'mc_run_dict23': {'(tau_u, tau_y)': (np.float64(0.8),
#    np.float64(0.6000000000000001)),
#   'run_idx': 23,
#   'prediction_loss_history': [np.float64(0.022010687052770064),
#    np.float64(0.06654340371587453),
#    np.float64(0.113507349629365)],
#   'prediction_loss_history_cf': [np.float64(0.022010687052770064),
#    np.float64(0.03511733771581599),
#    np.float64(0.019940078169160224)]},
#  'mc_run_dict24': {'(tau_u, tau_y)': (np.float64(0.8), np.float64(0.8)),
#   'run_idx': 24,
#   'prediction_loss_history': [np.float64(0.03071553913786905),
#    np.float64(0.09859632172006061),
#    np.float64(0.13961345350029225)],
#   'prediction_loss_history_cf': [np.float64(0.03071553913786905),
#    np.float64(0.09463203988759496),
#    np.float64(0.03433155036409687)]}}
